# %% [markdown]
# 実測値から予測したデータを見る

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sns
sns.set_style("white")

# %%
pred = pd.read_csv("../data/csv/forecastCloud.csv")

# %%
THRES = 2

thres_two = pred[pred["diff"].apply(lambda x: abs(x)) >= 2]
thres_four = pred[pred["diff"].apply(lambda x: abs(x)) >= 4]
thres_six = pred[pred["diff"].apply(lambda x: abs(x)) >= 6]

# %%
thres_two.describe()
# Out:
#                 時間         現地気圧         海面気圧          降水量           気温  \
# count  3975.000000  3975.000000  3975.000000  3975.000000  3975.000000
# mean     11.894843  1012.675170  1015.566717     0.002390    15.143145
# std       6.186622     7.096693     7.149142     0.062909     8.343770
# min       3.000000   982.600000   985.500000     0.000000    -3.100000
# 25%       6.000000  1008.200000  1011.100000     0.000000     8.400000
# 50%      12.000000  1012.900000  1015.700000     0.000000    13.700000
# 75%      18.000000  1017.600000  1020.500000     0.000000    21.100000
# max      21.000000  1033.800000  1036.800000     2.500000    36.200000
#
#               露点温度          蒸気圧           湿度           風速      降雪  \
# count  3975.000000  3975.000000  3975.000000  3975.000000  2242.0
# mean      7.061333    12.224629    60.789182     2.710591     0.0
# std       9.803400     8.367934    18.192848     1.409776     0.0
# ...

# %%
thres_four.describe()
# Out:
#                 時間         現地気圧         海面気圧     降水量           気温  \
# count  1793.000000  1793.000000  1793.000000  1793.0  1793.000000
# mean     11.886224  1012.682989  1015.577803     0.0    14.860457
# std       6.290706     7.251596     7.300394     0.0     8.090037
# min       3.000000   982.600000   985.500000     0.0    -0.700000
# 25%       6.000000  1008.300000  1011.100000     0.0     8.400000
# 50%      12.000000  1013.000000  1015.900000     0.0    13.300000
# 75%      18.000000  1017.600000  1020.500000     0.0    20.800000
# max      21.000000  1032.300000  1035.300000     0.0    36.200000
#
#               露点温度          蒸気圧           湿度           風速      降雪  \
# count  1793.000000  1793.000000  1793.000000  1793.000000  1012.0
# mean      7.059453    11.995538    61.708310     2.600892     0.0
# std       9.251800     7.941098    17.542812     1.347111     0.0
# min     -17.200000     1.600000    12.000000     0.100000     0.0
# ...

# %%
thres_six.describe()
# Out:
#                時間         現地気圧         海面気圧    降水量          気温        露点温度  \
# count  521.000000   521.000000   521.000000  521.0  521.000000  521.000000
# mean    12.765835  1012.860077  1015.750096    0.0   15.217466    8.817274
# std      6.592454     7.157539     7.193384    0.0    7.089707    8.604597
# min      3.000000   982.600000   985.500000    0.0   -0.700000  -17.200000
# 25%      6.000000  1008.600000  1011.400000    0.0    9.600000    2.900000
# 50%     15.000000  1013.700000  1016.600000    0.0   15.100000    8.600000
# 75%     18.000000  1017.800000  1020.800000    0.0   20.600000   15.800000
# max     21.000000  1031.500000  1034.500000    0.0   35.400000   27.000000
#
#               蒸気圧          湿度          風速     降雪          積雪     天気  \
# count  521.000000  521.000000  521.000000  264.0  264.000000  521.0
# mean    13.034165   67.399232    2.618618    0.0    0.075758    0.0
# std      7.217347   16.736933    1.348724    0.0    0.720384    0.0
# ...

# %%
sns.histplot(pred["diff"],bins=11,label="Diff")
plt.legend()
plt.savefig("../png/diff.png",facecolor="white")
plt.show()
